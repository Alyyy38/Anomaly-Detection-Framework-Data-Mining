# %% [markdown]
# # Model Training - Anomaly Detection Framework
#
# This notebook demonstrates how to train the anomaly detection model.

# %%
import torch
import sys
from pathlib import Path

sys.path.append('../')

from src.config import default_config
from src.data import CreditCardDataLoader, DataPreprocessor
from src.models import AnomalyDetectionFramework
from src.training import Trainer
